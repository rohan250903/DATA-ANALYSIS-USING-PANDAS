# %% [markdown]
# <a href="https://colab.research.google.com/github/rohan250903/DATA-ANALYSIS-USING-PANDAS/blob/main/DATA_ANALYSIS_USING_PANDAS_(_Movie_release_%26_Movie_Ratings).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-6ab5b66d-2362-4ec0-bef4-d05f4bcc158d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ab5b66d-2362-4ec0-bef4-d05f4bcc158d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #**MOVIE RELEASE ANALYSIS**

# %%
netflix=pd.read_csv('Netflix_Dataset_Movie.csv')
netflix
# Out:
#        Movie_ID  Year                                               Name
# 0             1  2003                                    Dinosaur Planet
# 1             2  2004                         Isle of Man TT 2004 Review
# 2             3  1997                                          Character
# 3             4  1994                       Paula Abdul's Get Up & Dance
# 4             5  2004                           The Rise and Fall of ECW
# ...         ...   ...                                                ...
# 17765     17766  2002  Where the Wild Things Are and Other Maurice Se...
# 17766     17767  2004                  Fidel Castro: American Experience
# 17767     17768  2000                                              Epoch
# 17768     17769  2003                                        The Company
# 17769     17770  2003                                       Alien Hunter
#
# [17770 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# ...

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17770 entries, 0 to 17769
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Movie_ID  17770 non-null  int64
#  1   Year      17770 non-null  int64
#  2   Name      17770 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 416.6+ KB

# %%
netflix.describe()
# Out:
#            Movie_ID          Year
# count  17770.000000  17770.000000
# mean    8885.500000   1990.235566
# std     5129.901477     16.564501
# min        1.000000   1915.000000
# 25%     4443.250000   1985.000000
# 50%     8885.500000   1997.000000
# 75%    13327.750000   2002.000000
# max    17770.000000   2005.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Movie_ID'].plot(kind='hist', bins=20, title='Movie_ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Year'].plot(kind='hist', bins=20, title='Year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
netflix.head()
# Out:
#    Movie_ID  Year                          Name
# 0         1  2003               Dinosaur Planet
# 1         2  2004    Isle of Man TT 2004 Review
# 2         3  1997                     Character
# 3         4  1994  Paula Abdul's Get Up & Dance
# 4         5  2004      The Rise and Fall of ECW
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7['Movie_ID'].plot(kind='hist', bins=20, title='Movie_ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8['Year'].plot(kind='hist', bins=20, title='Year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %% [markdown]
# ***MOVIES OF 90'S EVERGREEN ERA***

# %%
evergreen=netflix[netflix['Year']<2000]
evergreen
# Out:
#        Movie_ID  Year                          Name
# 2             3  1997                     Character
# 3             4  1994  Paula Abdul's Get Up & Dance
# 5             6  1997                          Sick
# 6             7  1992                         8 Man
# 8             9  1991      Class of Nuke 'Em High 2
# ...         ...   ...                           ...
# 17758     17759  1972             The Big Bird Cage
# 17761     17762  1997                       Gattaca
# 17762     17763  1978                     Interiors
# 17763     17764  1998           Shakespeare in Love
# 17764     17765  1969            Godzilla's Revenge
#
# [10823 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# evergreen['Movie_ID'].plot(kind='hist', bins=20, title='Movie_ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %% [markdown]
# ***BLACK & WHITE MOVIES***

# %%
evergreen=netflix[netflix['Year']<1925]
evergreen
# Out:
#        Movie_ID  Year                                               Name
# 233         234  1921                     Animation Legend: Winsor McCay
# 236         237  1918                                    Broken Blossoms
# 369         370  1918                                            Chaplin
# 393         394  1916                                                 20
# 1406       1407  1921                               Orphans of the Storm
# 2020       2021  1922                                         Robin Hood
# 2643       2644  1924                                    Thief of Bagdad
# 2846       2847  1920                                  The Mark of Zorro
# 3136       3137  1915                                       Les Vampires
# 3386       3387  1916                                        Intolerance
# 3456       3457  1920   Slapstick Symposium: The Harold Lloyd Collection
# 3553       3554  1924                                     The Last Laugh
# ...

# %% [markdown]
# ***MOVIES RELEASED IN 2004***

# %%
evergreen=netflix[netflix['Year']==2004]
evergreen
# Out:
#        Movie_ID  Year                                               Name
# 1             2  2004                         Isle of Man TT 2004 Review
# 4             5  2004                           The Rise and Fall of ECW
# 7             8  2004                         What the #$*! Do We Know!?
# 25           26  2004                                    Never Die Alone
# 31           32  2004  ABC Primetime: Mel Gibson's The Passion of the...
# ...         ...   ...                                                ...
# 17737     17738  2004                   Henry Rollins: Live at Luna Park
# 17740     17741  2004                          Ginger Snaps 2: Unleashed
# 17743     17744  2004                         NASCAR: Tony Stewart Smoke
# 17759     17760  2004                                      Lightning Bug
# 17766     17767  2004                  Fidel Castro: American Experience
#
# [1436 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# ...

# %% [markdown]
# ***LIST OF MOVIES RELEASED SINCE 1915***

# %%
evergreen=netflix.sort_values('Year')
evergreen
# Out:
#        Movie_ID  Year                                               Name
# 4793       4794  1915        Ancient Civilizations: Land of the Pharaohs
# 10781     10782  1915                             Roti Kapada Aur Makaan
# 13146     13147  1915                 Chaplin's Essanay Comedies: Vol. 1
# 16677     16678  1915                                    Jimmy Hollywood
# 8820       8821  1915                              The Birth of a Nation
# ...         ...   ...                                                ...
# 12438     12439  2005          Strawberry Shortcake: Moonlight Mysteries
# 9104       9105  2005                                  A Slice of Terror
# 4386       4387  2005                                       Nobody Knows
# 4399       4400  2005  Disney Princess Stories: Vol. 3: Beauty Shines...
# 6599       6600  2005                                     Time and Again
#
# [17770 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# ...

# %% [markdown]
# ***LIST OF MOVIES STARTING WITH 'A'***

# %%
evergreen=netflix['Name']
ctr=0
for s in evergreen:
    if s.startswith('A'):
      print(s)
# Out:
# ABC Primetime: Mel Gibson's The Passion of the Christ
# Aqua Teen Hunger Force: Vol. 1
# Ashtanga Yoga: Beginner's Practice with Nicki Doane
# A Yank in the R.A.F.
# At Home Among Strangers
# Antarctica: IMAX
# A Fishy Story
# Arachnid
# Allergies: A Natural Approach
# A Little Princess
# A Killer Within
# Adam-12: Season 1
# Airplane II: The Sequel
# Arliss: The Best of Arliss
# Animation Legend: Winsor McCay
# A Night at the Opera
# Animal
# Angelina Ballerina: Lights
# Ace Ventura: When Nature Calls
# Absolutely Fabulous: Series 5
# Arjuna: Complete Collection
# A Night in Casablanca
# Agatha Christie's Poirot: Sad Cypress
# A Thousand Acres
# Avenging Angelo
# Avia Vampire Hunter
# Angie
# A Crime of Passion
# American Beauty
# Alice in Wonderland (TV Version)
# An Ideal Husband
# Armageddon
# American Tragedy
# Angel's Dance
# A Change of Heart
# Africans in America: America's Journey Through Slavery
# Abigail's Party
# A Slipping Down Life
# A Hole in the Head
# ...

# %% [markdown]
# ***TOP 25 MOVIES***

# %%
evergreen=netflix[netflix['Movie_ID']<=26]
evergreen
# Out:
#     Movie_ID  Year                                               Name
# 0          1  2003                                    Dinosaur Planet
# 1          2  2004                         Isle of Man TT 2004 Review
# 2          3  1997                                          Character
# 3          4  1994                       Paula Abdul's Get Up & Dance
# 4          5  2004                           The Rise and Fall of ECW
# 5          6  1997                                               Sick
# 6          7  1992                                              8 Man
# 7          8  2004                         What the #$*! Do We Know!?
# 8          9  1991                           Class of Nuke 'Em High 2
# 9         10  2001                                            Fighter
# 10        11  1999                     Full Frame: Documentary Shorts
# 11        12  1947                               My Favorite Brunette
# ...

# %% [markdown]
# ***MOVIES IN 1917***

# %%
evergreen=netflix[netflix['Year']==1917]
evergreen
# Out:
#       Movie_ID  Year                          Name
# 4187      4188  1917             Slapstick Masters
# 4754      4755  1917  The Cook and Other Treasures
# 9809      9810  1917       Chaplin Mutuals: Vol. 1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# evergreen['Movie_ID'].plot(kind='hist', bins=20, title='Movie_ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# evergreen.groupby('Name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
# ...

# %% [markdown]
# ***MOVIES RELEASED IN 2015***

# %%
evergreen=netflix[netflix['Year']==2015]
evergreen
# Out:
# Empty DataFrame
# Columns: [Movie_ID, Year, Name]
# Index: []

# %% [markdown]
# #**MOVIE RATINGS ANALYSIS**

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-9039dc59-f85b-4da9-a117-eddb83af91b5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9039dc59-f85b-4da9-a117-eddb83af91b5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
movies=pd.read_csv('Netflix_Dataset_Rating.csv')
movies
# Out:
#           User_ID  Rating  Movie_ID
# 0          712664       5         3
# 1         1331154       4         3
# 2         2632461       3         3
# 3           44937       5         3
# 4          656399       4         3
# ...           ...     ...       ...
# 17337453   520675       3      4496
# 17337454  1055714       5      4496
# 17337455  2643029       4      4496
# 17337456  1559566       3      4496
# 17337457   293198       3      4496
#
# [17337458 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# movies['User_ID'].plot(kind='hist', bins=20, title='User_ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# movies['Rating'].plot(kind='hist', bins=20, title='Rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17337458 entries, 0 to 17337457
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   User_ID   int64
#  1   Rating    int64
#  2   Movie_ID  int64
# dtypes: int64(3)
# memory usage: 396.8 MB

# %%
movies.describe()
# Out:
#             User_ID        Rating      Movie_ID
# count  1.733746e+07  1.733746e+07  1.733746e+07
# mean   1.321158e+06  3.590570e+00  2.302783e+03
# std    7.646923e+05  1.062665e+00  1.303458e+03
# min    6.000000e+00  1.000000e+00  3.000000e+00
# 25%    6.602280e+05  3.000000e+00  1.176000e+03
# 50%    1.316775e+06  4.000000e+00  2.342000e+03
# 75%    1.983213e+06  4.000000e+00  3.433000e+03
# max    2.649429e+06  5.000000e+00  4.496000e+03
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['User_ID'].plot(kind='hist', bins=20, title='User_ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Rating'].plot(kind='hist', bins=20, title='Rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
movies.head()
# Out:
#    User_ID  Rating  Movie_ID
# 0   712664       5         3
# 1  1331154       4         3
# 2  2632461       3         3
# 3    44937       5         3
# 4   656399       4         3
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['User_ID'].plot(kind='hist', bins=20, title='User_ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['Rating'].plot(kind='hist', bins=20, title='Rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_10.plot(kind='scatter', x='User_ID', y='Rating', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %% [markdown]
# ***SUPER BUMBER HIT MOVIES***

# %%
ever=movies[movies['Rating']==5]
ever
# Out:
#           User_ID  Rating  Movie_ID
# 0          712664       5         3
# 3           44937       5         3
# 16          66414       5         3
# 17        2519847       5         3
# 22        2158448       5         3
# ...           ...     ...       ...
# 17337429  2087152       5      4496
# 17337440  2082805       5      4496
# 17337450   196584       5      4496
# 17337452   823628       5      4496
# 17337454  1055714       5      4496
#
# [3769803 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_16['User_ID'].plot(kind='hist', bins=20, title='User_ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['Movie_ID'].plot(kind='hist', bins=20, title='Movie_ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %% [markdown]
# ***MOVIE_ID IN ASCENDING ORDER***

# %%
ever=movies.sort_values('Movie_ID')
ever
# Out:
#           User_ID  Rating  Movie_ID
# 0          712664       5         3
# 1021      2148273       2         3
# 1020       524628       4         3
# 1019       328293       3         3
# 1018       639533       4         3
# ...           ...     ...       ...
# 17332226  1289189       3      4496
# 17332225   130255       5      4496
# 17332224   760481       3      4496
# 17332222  2556070       3      4496
# 17337457   293198       3      4496
#
# [17337458 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_25['User_ID'].plot(kind='hist', bins=20, title='User_ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_26['Rating'].plot(kind='hist', bins=20, title='Rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
ever=movies.sort_values('Rating')
ever
# Out:
#           User_ID  Rating  Movie_ID
# 10762457  1454488       1      2868
# 12981751  2123226       1      3427
# 4193267   1355926       1      1145
# 8467902   1693704       1      2235
# 9512687   1528653       1      2495
# ...           ...     ...       ...
# 11458990    77504       5      3086
# 11458983   440555       5      3086
# 11458978  1689621       5      3086
# 11459035  2083947       5      3086
# 0          712664       5         3
#
# [17337458 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_36['User_ID'].plot(kind='hist', bins=20, title='User_ID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_37['Rating'].plot(kind='hist', bins=20, title='Rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %% [markdown]
# ***ID:3***

# %%
evero=movies[movies['Movie_ID']<4]
evero
# Out:
#       User_ID  Rating  Movie_ID
# 0      712664       5         3
# 1     1331154       4         3
# 2     2632461       3         3
# 3       44937       5         3
# 4      656399       4         3
# ...       ...     ...       ...
# 1519  1607300       5         3
# 1520  2456457       4         3
# 1521  1961675       4         3
# 1522   262367       2         3
# 1523   520675       4         3
#
# [1524 rows x 3 columns]

# %% [markdown]
# ***LIST OF ALL MOVIES'S USER ID***

# %%
ever=movies['User_ID']
ever
# Out:
# 0            712664
# 1           1331154
# 2           2632461
# 3             44937
# 4            656399
#              ...
# 17337453     520675
# 17337454    1055714
# 17337455    2643029
# 17337456    1559566
# 17337457     293198
# Name: User_ID, Length: 17337458, dtype: int64

# %% [markdown]
# ***FLOP MOVIES***

# %%
ever=movies[movies['Rating']==1]
ever
# Out:
#           User_ID  Rating  Movie_ID
# 5          439011       1         3
# 36        2143489       1         3
# 44        1854303       1         3
# 53        2173816       1         3
# 71          52540       1         3
# ...           ...     ...       ...
# 17337231   172618       1      4496
# 17337265   834896       1      4496
# 17337391  2634967       1      4496
# 17337418   559886       1      4496
# 17337438   611936       1      4496
#
# [721356 rows x 3 columns]
